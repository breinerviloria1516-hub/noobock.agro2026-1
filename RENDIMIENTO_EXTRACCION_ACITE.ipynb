# %% [markdown]
# <a href="https://colab.research.google.com/github/breinerviloria1516-hub/noobock.agro2026-1/blob/main/RENDIMIENTO_EXTRACCION_ACITE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento**:
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos**:
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L (R)
# .
# $$Pa=Lt     * 0.92$$
# $$ R=(Pa/Pr)*100$$
# **Prueba del programa**:
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: solicitar el nombre del lote de produccion (tipo string)
# solicitar el peso de los racimos en kg (tipo float).(pr)
#solicitar los litros de aceite obtenidos (tipo float)(lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# proceso: calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa / pr) * 100

# SALIDA: informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# ### Explicación Línea por Línea del Código de Control de Rendimiento en Extracción de Aceite
#
# El siguiente código Python realiza los cálculos necesarios para determinar el Índice de Rendimiento de Extracción (IRE) de aceite de palma.
#
# ```python
# # ENTRADA: solicitar el nombre del lote de produccion (tipo string)
# # solicitar el peso de los racimos en kg (tipo float).(pr)
# #solicitar los litros de aceite obtenidos (tipo float)(lt)
# ```
# Estas líneas son comentarios (indicados por `#`) que describen las próximas acciones del programa, específicamente la parte de "ENTRADA" donde se solicitarán datos al usuario. Indican qué tipo de datos se esperan y el nombre de las variables que se usarán (`pr` para peso de racimos, `lt` para litros de aceite).
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# Esta línea utiliza la función `input()` para mostrar el mensaje "Ingrese el nombre del lote: " al usuario. El texto que el usuario ingrese será almacenado como una cadena de caracteres (string) en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Similar a la anterior, `input()` solicita al usuario el peso de los racimos. Sin embargo, en este caso, la entrada del usuario se pasa a la función `float()`. Esto convierte la cadena de texto ingresada por el usuario en un número de punto flotante (decimal), que es necesario para realizar cálculos matemáticos. El resultado se guarda en la variable `pr` (peso de los racimos).
#
# ```python
# lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# De manera análoga, esta línea solicita al usuario la cantidad de aceite obtenido en litros y la convierte a un número de punto flotante usando `float()`, almacenando el valor en la variable `lt` (litros de aceite).
#
# ```python
# # proceso: calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Otro comentario, esta vez indicando la sección de "PROCESO" donde se realizarán los cálculos principales.
#
# ```python
# pa = lt * 0.92
# ```
# Aquí se calcula el peso del aceite (`pa`). Se multiplica la cantidad de litros de aceite (`lt`) por su densidad (0.92 kg/L). El resultado es el peso del aceite en kilogramos, almacenado en `pa`.
#
# ```python
# r = (pa / pr) * 100
# ```
# Esta es la fórmula principal para calcular el rendimiento (`r`). Se divide el peso del aceite (`pa`) por el peso total de los racimos (`pr`), y luego se multiplica por 100 para obtener un porcentaje. El resultado se guarda en la variable `r`.
#
# ```python
# # SALIDA: informar el rendimiento del lote
# ```
# Un comentario que marca la sección de "SALIDA", donde se presentarán los resultados al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Finalmente, la función `print()` se utiliza para mostrar el resultado al usuario. Concatena varias cadenas de texto y los valores de las variables `nombre` y `r` para formar un mensaje legible que informa el rendimiento del lote.
